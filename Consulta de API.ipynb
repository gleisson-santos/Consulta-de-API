# %%
import requests
import json

cotacoes = requests.get('https://economia.awesomeapi.com.br/json/all')
cotacoes_dic = cotacoes.json()
print(cotacoes_dic)
# Out:
# {'USD': {'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '5.3307', 'low': '5.2428', 'varBid': '0.067', 'pctChange': '1.27', 'bid': '5.3291', 'ask': '5.3301', 'timestamp': '1665772241', 'create_date': '2022-10-14 15:30:41'}, 'USDT': {'code': 'USD', 'codein': 'BRLT', 'name': 'Dólar Americano/Real Brasileiro Turismo', 'high': '5.355', 'low': '5.275', 'varBid': '0.05', 'pctChange': '0.94', 'bid': '5.2', 'ask': '5.51', 'timestamp': '1665772020', 'create_date': '2022-10-14 15:27:00'}, 'CAD': {'code': 'CAD', 'codein': 'BRL', 'name': 'Dólar Canadense/Real Brasileiro', 'high': '3.8405', 'low': '3.8035', 'varBid': '0.0082', 'pctChange': '0.21', 'bid': '3.8341', 'ask': '3.8347', 'timestamp': '1665772242', 'create_date': '2022-10-14 15:30:42'}, 'GBP': {'code': 'GBP', 'codein': 'BRL', 'name': 'Libra Esterlina/Real Brasileiro', 'high': '5.9788', 'low': '5.8723', 'varBid': '-0.0089', 'pctChange': '-0.15', 'bid': '5.9504', 'ask': '5.9535', 'timestamp': '1665772241', 'create_date': '2022-10-14 15:30:41'}, 'ARS': {'code': 'ARS', 'codein': 'BRL', 'name': 'Peso Argentino/Real Brasileiro', 'high': '0.0352', 'low': '0.0345', 'varBid': '0.0003', 'pctChange': '0.86', 'bid': '0.0351', 'ask': '0.0351', 'timestamp': '1665772240', 'create_date': '2022-10-14 15:30:40'}, 'BTC': {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '104.857', 'low': '100.84', 'varBid': '2298', 'pctChange': '2.28', 'bid': '102.836', 'ask': '103.017', 'timestamp': '1665771623', 'create_date': '2022-10-14 15:20:23'}, 'LTC': {'code': 'LTC', 'codein': 'BRL', 'name': 'Litecoin/Real Brasileiro', 'high': '279', 'low': '266.92', 'varBid': '6.12', 'pctChange': '2.3', 'bid': '272.85', 'ask': '273.83', 'timestamp': '1665771622', 'create_date': '2022-10-14 15:20:22'}, 'EUR': {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '5.1834', 'low': '5.1061', 'varBid': '0.0374', 'pctChange': '0.73', 'bid': '5.1809', 'ask': '5.1823', 'timestamp': '1665772244', 'create_date': '2022-10-14 15:30:44'}, 'JPY': {'code': 'JPY', 'codein': 'BRL', 'name': 'Iene Japonês/Real Brasileiro', 'high': '0.03585', 'low': '0.03549', 'varBid': '0', 'pctChange': '0', 'bid': '0.03581', 'ask': '0.03583', 'timestamp': '1665772245', 'create_date': '2022-10-14 15:30:45'}, 'CHF': {'code': 'CHF', 'codein': 'BRL', 'name': 'Franco Suíço/Real Brasileiro', 'high': '5.2996', 'low': '5.2345', 'varBid': '0.0393', 'pctChange': '0.75', 'bid': '5.2962', 'ask': '5.2992', 'timestamp': '1665772243', 'create_date': '2022-10-14 15:30:43'}, 'AUD': {'code': 'AUD', 'codein': 'BRL', 'name': 'Dólar Australiano/Real Brasileiro', 'high': '3.3391', 'low': '3.2931', 'varBid': '-0.0088', 'pctChange': '-0.26', 'bid': '3.3038', 'ask': '3.3053', 'timestamp': '1665772243', 'create_date': '2022-10-14 15:30:43'}, 'CNY': {'code': 'CNY', 'codein': 'BRL', 'name': 'Yuan Chinês/Real Brasileiro', 'high': '0.7412', 'low': '0.7295', 'varBid': '0.0082', 'pctChange': '1.12', 'bid': '0.7411', 'ask': '0.7412', 'timestamp': '1665772204', 'create_date': '2022-10-14 15:30:04'}, 'ILS': {'code': 'ILS', 'codein': 'BRL', 'name': 'Novo Shekel Israelense/Real Brasileiro', 'high': '1.5011', 'low': '1.4783', 'varBid': '0.0187', 'pctChange': '1.26', 'bid': '1.4976', 'ask': '1.4979', 'timestamp': '1665772206', 'create_date': '2022-10-14 15:30:06'}, 'ETH': {'code': 'ETH', 'codein': 'BRL', 'name': 'Ethereum/Real Brasileiro', 'high': '7.05', 'low': '6.70035', 'varBid': '227.52', 'pctChange': '3.38', 'bid': '6.95378', 'ask': '6.96707', 'timestamp': '1665771622', 'create_date': '2022-10-14 15:20:22'}, 'XRP': {'code': 'XRP', 'codein': 'BRL', 'name': 'XRP/Real Brasileiro', 'high': '2.8', 'low': '2.53', 'varBid': '0.09', 'pctChange': '3.56', 'bid': '2.63', 'ask': '2.63', 'timestamp': '1665771621', 'create_date': '2022-10-14 15:20:21'}, 'DOGE': {'code': 'DOGE', 'codein': 'BRL', 'name': 'Dogecoin/Real Brasileiro', 'high': '0.320594', 'low': '0.309924', 'varBid': '0.001017', 'pctChange': '0.32', 'bid': '0.314076 ...

# %%
print('Dolar {}'.format(cotacoes_dic['USD']['bid']))
print('Euro {}'.format(cotacoes_dic['EUR']['bid']))
print('Bitcoin {}'.format(cotacoes_dic['BTC']['bid']))
# Out:
# Dolar 5.3291
# Euro 5.1809
# Bitcoin 102.836

# %%
cotacoes_dolar30 = requests.get('https://economia.awesomeapi.com.br/json/daily/USD-BRL/30')
cotacoes_dolar30_dic = cotacoes_dolar30.json()
lista_cotacoes_dolar = [float(item['bid']) for item in cotacoes_dolar30_dic]
print(lista_cotacoes_dolar)
# Out:
# [5.2941, 5.2605, 5.293, 5.2929, 5.1881, 5.201, 5.2032, 5.2217, 5.1961, 5.1768, 5.1646, 5.4084, 5.3973, 5.376, 5.3791, 5.3906, 5.2599, 5.2633, 5.2625, 5.1171, 5.1716, 5.1425, 5.1723, 5.2541, 5.2486, 5.247, 5.1641, 5.1903, 5.093, 5.1465]

# %%
cotacoes_btc = requests.get('https://economia.awesomeapi.com.br/json/daily/BTC-BRL/500?start_date=20220101&end_date=20220531')
cotacoes_btc = cotacoes_btc.json()
cotacoes_btc = [float(item['bid']) for item in cotacoes_btc]
cotacoes_btc.reverse()
print(cotacoes_btc)
print(len(cotacoes_btc))
# Out:
# [268.0, 267.34, 264.911, 262.001, 251.225, 247.533, 236.0, 238.019, 238.359, 238.083, 240.006, 245.346, 237.947, 239.745, 240.639, 240.612, 234.757, 237.353, 229.413, 222.75, 200.302, 193.277, 200.292, 203.675, 203.535, 202.814, 201.953, 204.283, 206.375, 206.2, 205.145, 205.55, 196.413, 197.522, 220.998, 222.538, 225.905, 232.964, 234.123, 233.535, 230.011, 223.5, 222.865, 222.687, 223.3, 231.147, 226.616, 211.66, 207.542, 207.589, 200.198, 190.157, 195.9, 188.583, 197.358, 203.789, 202.702, 196.451, 222.192, 227.91, 225.113, 215.0, 200.011, 201.634, 195.812, 195.025, 196.779, 210.997, 199.023, 197.25, 198.0, 193.245, 202.462, 201.728, 208.684, 206.721, 210.778, 212.688, 207.898, 204.01, 209.119, 208.49, 212.709, 212.0, 212.453, 222.999, 225.509, 227.61, 226.167, 218.0, 217.842, 215.9, 218.0, 215.993, 213.025, 205.401, 208.521, 200.711, 202.882, 200.638, 187.27, 189.366, 194.343, 188.884, 191.721, 191.719, 188.05, 190.949, 194.746, 192.54, 188.792, 191.62, 190.509, 190.606, 197.622, 191.12, 195.346, 197.312, 192.795, 188.645, 192.293, 195.355, 188.256, 195.505, 185.115, 184.1, 181.907, 175.173, 157.15, 160.658, 149.904, 150.194, 149.469, 154.052, 159.962, 152.0, 151.288, 143.8, 150.384, 143.8, 144.822, 149.009, 141.526, 144.212, 143.115, 141.501, 136.127, 138.505, 140.252, 151.656, 151.5]
# 151

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(15, 5))
plt.plot(cotacoes_btc)
plt.xlabel(15)
plt.ylabel(15)
plt.title('Grafico')
plt.show()

# %%
# Out:
# Dolar 5.1885
# Euro 5.4666
# Bitcoin 106.674
